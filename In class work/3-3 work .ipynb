# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,0.5,0.8])

# %%
fig = plt.figure()
#starting points (0,0) , then how much of screen you want it to take up (0.5,1)
ax1 = fig.add_axes([0,0,0.5,1], facecolor = 'lemonchiffon')
ax2 = fig.add_axes([0.6,0,0.5,1], projection ='polar')

# %% [markdown]
# ## subplots

# %%
fig = plt.figure()
axes = fig.subplots(nrows=2, ncols=3)
#edit 1 plot
axes[0,1]
# Out:
# <Axes: >

# %%
fig = plt.figure()
axes = fig.subplots(nrows=2, ncols=3)
axes[0,1].plot([0.2,0.4,0.6],[0.2,0.4,0.6])

# %%
fig = plt.figure()
fig.add_subplot(2,2,1)
#across rows then columns
fig.add_subplot(2,2,2)
fig.add_subplot(2,2,3)
fig.add_subplot(2,2,4)
# Out:
# <Axes: >

# %%
fig = plt.figure(figsize=(12,6))
axes= fig.subplots(nrows=2, ncols=3)
